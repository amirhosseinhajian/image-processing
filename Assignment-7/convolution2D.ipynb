# %% [markdown]
# Import libraries and image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("./inputs/car.jpg")
plt.imshow(img)

# %% [markdown]
# Edge detection filter

# %%
kernel = np.array([[-1 , -1 , -1],
                   [-1 ,  8 , -1],
                   [-1 , -1 , -1]])
edges_img = cv2.filter2D(img, -1, kernel)
edges_img = np.hstack((img, edges_img))
plt.imshow(edges_img)
cv2.imwrite("./outputs/edges_car.jpg", edges_img)
# Out:
# True

# %% [markdown]
# Sharpening filter

# %%
kernel = np.array([[0  , -1 ,  0],
                   [-1 ,  5 , -1],
                   [0  , -1 ,  0]])
img_sharped = cv2.filter2D(img, -1, kernel)
img_sharped = np.hstack((img, img_sharped))
plt.imshow(img_sharped)
cv2.imwrite("./outputs/sharped_car.jpg", img_sharped)
# Out:
# True

# %% [markdown]
# Emboss filter

# %%
kernel = np.array([[-2 , -1 ,  0],
                   [-1 ,  1 ,  1],
                   [0  ,  1 ,  2]])
embossed_car = cv2.filter2D(img, -1, kernel)
embossed_car = np.hstack((img, embossed_car))
plt.imshow(embossed_car)
cv2.imwrite("./outputs/embossed_car_car.jpg", embossed_car)
# Out:
# True

# %% [markdown]
# Identity filter

# %%
kernel = np.array([[0  ,  0 ,  0],
                   [0  ,  1 ,  0],
                   [0  ,  0 ,  0]])
identity_car = cv2.filter2D(img, -1, kernel)
identity_car = np.hstack((img, identity_car))
plt.imshow(identity_car)
cv2.imwrite("./outputs/identity_car.jpg", identity_car)
# Out:
# True

# %% [markdown]
# 5*5 Edge detection filter

# %%
kernel = np.array([[-1  ,  -1 ,  -1, -1, -1],
                   [-1  ,  -1 ,  4, -1, -1],
                   [-1  ,  4 ,  4, 4, -1],
                   [-1, -1, 4, -1, -1],
                   [-1, -1, -1, -1, -1]])
edge_img2 = cv2.filter2D(img, -1, kernel)
edge_img2 = np.hstack((img, edge_img2))
plt.imshow(edge_img2)
cv2.imwrite("./outputs/edge_img2_car.jpg", edge_img2)
# Out:
# True
